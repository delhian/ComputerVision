# %% [markdown]
# <a href="https://colab.research.google.com/github/delhian/ComputerVision/blob/main/keras/keras_layers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Model, Sequential, layers
import numpy as np

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
model = Sequential([
  layers.InputLayer(400),
  layers.Dense(300),
  layers.Dense(200),
  layers.Dense(100),
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 300)               120300
#
#  dense_1 (Dense)             (None, 200)               60200
#
#  dense_2 (Dense)             (None, 100)               20100
#
# =================================================================
# Total params: 200,600
# Trainable params: 200,600
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
layers.Concatenate(axis=1)([x, y])

# %%
input = keras.Input(shape=(1000,))
inp = input
i = 0
while i<=3:
  i += 1
  output = layers.Dense(1000, 'relu')(inp)
  output = layers.Concatenate()([output, inp])
  inp = output

model = Model(inputs=input, outputs=output)
model.summary()
# Out:
# Model: "model_28"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_35 (InputLayer)          [(None, 1000)]       0           []
#
#  dense_127 (Dense)              (None, 1000)         1001000     ['input_35[0][0]']
#
#  concatenate_97 (Concatenate)   (None, 2000)         0           ['dense_127[0][0]',
#                                                                   'input_35[0][0]']
#
#  dense_128 (Dense)              (None, 1000)         2001000     ['concatenate_97[0][0]']
#
#  concatenate_98 (Concatenate)   (None, 3000)         0           ['dense_128[0][0]',
#                                                                   'concatenate_97[0][0]']
#
#  dense_129 (Dense)              (None, 1000)         3001000     ['concatenate_98[0][0]']
#
#  concatenate_99 (Concatenate)   (None, 4000)         0           ['dense_129[0][0]',
#                                                                   'concatenate_98[0][0]']
#
#  dense_130 (Dense)              (None, 1000)         4001000     ['concatenate_99[0][0]']
#
#  concatenate_100 (Concatenate)  (None, 5000)         0           ['dense_130[0][0]',
#                                                                   'concatenate_99[0][0]']
#
# ==================================================================================================
# Total params: 10,004,000
# Trainable params: 10,004,000
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from tensorflow.keras.applications import Xception
import matplotlib.pyplot as plt

model = Xception(include_top=False, input_shape=(150, 150, 3))
 
def count_weights_in_layer(layer):
  array_lengths = [len(W.flat) for W in layer.get_weights()]
  return sum(array_lengths)
 
W = [count_weights_in_layer(layer) for layer in model.layers]

plt.plot(W)
plt.show()

# %%
from tensorflow.keras import layers, Sequential
model = Sequential([
  layers.Flatten(),
  layers.Dense(100, 'relu'),
  layers.Dense(10, 'softmax')
])
 
input = np.zeros((64, 256, 256, 3))
model(input).numpy().shape #(64, 10)
# Out:
# (64, 10)

# %%
256 * 256 * 3 * 100 + 100
# Out:
# 19660900

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (64, 196608)              0
#
#  dense_131 (Dense)           (64, 100)                 19660900
#
#  dense_132 (Dense)           (64, 10)                  1010
#
# =================================================================
# Total params: 19,661,910
# Trainable params: 19,661,910
# Non-trainable params: 0
# _________________________________________________________________
